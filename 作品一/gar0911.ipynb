# %% [markdown]
# <hr>
# <font color=skyblue> 繪製常態分配的 PDF 函數</font>
#
# 1. 繪製常態分配PDF函數
# 2. 繪製常態分配的CDF函數
# <hr>

# %%
# draw a pdf of a normal distribution
import numpy as np
import matplotlib.pyplot  as plt
import scipy.stats as stats
import math
x = np.arange(-10, 10, 0.01) 
#y = 1/(math.sqrt(2*math.pi)) * np.exp(-x**2/2)
#y = np.exp(-x**2/2)
y = stats.norm.pdf(x, 0, 1)
plt.figure()
# plt.plot(x, y, linewidth = 2, color = 'b')
plt.title('Normal Distribution')
plt.xlabel('X')
#y = 1/(math.sqrt(2*math.pi)) * np.exp(-x**2/2)
plt.ylabel('Probability Density')
plt.plot(x, y, linewidth = 3, color = 'y')
plt.grid()
plt.savefig('normal_distribution.png')
# plt.savefig('normal_distribution.png')
plt.show()
# plt.close()
# plt.savefig('normal_distribution.png')

# %%
pip install scipy
# Out:
# Collecting spicy
#   Downloading spicy-0.16.0-py2.py3-none-any.whl.metadata (310 bytes)
# Collecting scipy (from spicy)
#   Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scipy->spicy) (2.1.1)
# Downloading spicy-0.16.0-py2.py3-none-any.whl (1.7 kB)
# Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_x86_64.whl (25.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 273.7 kB/s eta 0:00:0000:0100:03
# Installing collected packages: scipy, spicy
# Successfully installed scipy-1.14.1 spicy-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
#   Cell In[7], line 1
#     pip install numpy
#         ^
# SyntaxError: invalid syntax

# %%
pip install matplotlib
# Out:
#   Cell In[17], line 1
#     pip install matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp312-cp312-macosx_10_12_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp312-cp312-macosx_10_9_universal2.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp312-cp312-macosx_10_9_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/darrybae/Library/Python/3.12/lib/python/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp312-cp312-macosx_10_10_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/darrybae/Library/Python/3.12/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/darrybae/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp312-cp312-macosx_10_12_x86_64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 126.8 kB/s eta 0:00:0000:0100:03
# Downloading contourpy-1.3.0-cp312-cp312-macosx_10_9_x86_64.whl (267 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp312-cp312-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 144.3 kB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.7-cp312-cp312-macosx_10_9_x86_64.whl (65 kB)
# Downloading pillow-10.4.0-cp312-cp312-macosx_10_10_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 177.2 kB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.4
# Note: you may need to restart the kernel to use updated packages.
