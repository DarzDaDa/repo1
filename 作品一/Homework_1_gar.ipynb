# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))


# First subplot: Normal distribution with different standard deviations
mu = 0
sigma = [0.5, 1, 2, 3, 4, 5]
x = np.linspace(-10, 10, 1000)
for s in sigma:
    y = norm.pdf(x, mu, s)
    ax1.plot(x, y, label=f'$\sigma$ = {s}')
ax1.set_title('Normal Distribution with Different Standard Deviations')
ax1.set_xlabel('x')
ax1.set_ylabel('Probability Density Function')
ax1.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)
ax1.legend()

# Second subplot: Normal distribution with different means
mu = [0, 1, 2, 3, 4, 5]
sigma = 1
x = np.linspace(-5, 10, 1000)
for m in mu:
    y = norm.pdf(x, m, sigma)
    ax2.plot(x, y, label=f'$\mu$ = {m}')
ax2.set_title('Normal Distribution with Different Means')
ax2.set_xlabel('x')
ax2.set_ylabel('Probability Density Function')
ax2.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)
ax2.legend()

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/2m/4ztlb_p94yz21fypbmv8lvcr0000gn/T/ipykernel_94517/764322914.py:14: SyntaxWarning: invalid escape sequence '\s'
#   ax1.plot(x, y, label=f'$\sigma$ = {s}')
# /var/folders/2m/4ztlb_p94yz21fypbmv8lvcr0000gn/T/ipykernel_94517/764322914.py:27: SyntaxWarning: invalid escape sequence '\m'
#   ax2.plot(x, y, label=f'$\mu$ = {m}')

# %%
import numpy as np
import matplotlib.pyplot as plt


# Set the parameters for the normal distribution
mu = 0  # mean
sigma = 1  # standard deviation
sample_size = 100000  # number of samples

# Generate random variables from the normal distribution
data = np.random.normal(mu, sigma, sample_size)

# Plot the histogram
plt.figure(figsize=(5, 3))
plt.hist(data, bins=30, edgecolor='gray', alpha=0.7)

# Add titles and labels
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Show the plot
plt.show()

import numpy as np
import matplotlib.pyplot as plt

# Set the parameters for the normal distribution
mu = 0  # mean
sigma = 1  # standard deviation
sample_size = 10000  # number of samples

# Generate random variables from the normal distribution
data = np.random.normal(mu, sigma, sample_size)

# Plot the boxplot
plt.figure(figsize=(5, 3))
plt.boxplot(data, vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))

# Add titles and labels
plt.title('Boxplot of Normally Distributed Data')
plt.xlabel('Value')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Show the plot
plt.show()

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Set the parameters for the normal distribution
mu = 0  # mean
sigma = 1  # standard deviation
sample_size = 1000  # number of samples

# Generate random variables from the normal distribution
data = np.random.normal(mu, sigma, sample_size)

# Generate the Q-Q plot
plt.figure(figsize=(5, 3))
stats.probplot(data, dist="norm", plot=plt)

# Change the color of the points
plt.gca().get_lines()[0].set_color('blue')


# Add titles and labels
plt.title('Normal Probability Plot')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Show the plot
plt.show()

import numpy as np
import matplotlib.pyplot as plt

# Set the parameters for the normal distribution
mu = 0  # mean
sigma = 1  # standard deviation
sample_size = 10000  # number of samples

# Generate random variables from the normal distribution
data = np.random.normal(mu, sigma, sample_size)

# Sort the data
sorted_data = np.sort(data)

# Calculate the empirical CDF values
ecdf = np.arange(1, sample_size + 1) / sample_size

# Plot the empirical CDF
plt.figure(figsize=(5, 3))
plt.step(sorted_data, ecdf, where='post', color='blue', label='Empirical CDF')

# Add titles and labels
plt.title('Empirical CDF of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('ECDF')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Set the parameters for the normal distribution
mu = 0  # mean
sigma = 1  # standard deviation

# Create a figure with four subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# First subplot: Histogram
sample_size = 100000  # number of samples
data = np.random.normal(mu, sigma, sample_size)
axs[0, 0].hist(data, bins=30, edgecolor='gray', alpha=0.7)
axs[0, 0].set_title('Histogram of Normally Distributed Data')
axs[0, 0].set_xlabel('Value')
axs[0, 0].set_ylabel('Frequency')
axs[0, 0].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Second subplot: Boxplot
sample_size = 10000  # number of samples
data = np.random.normal(mu, sigma, sample_size)
axs[0, 1].boxplot(data, vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
axs[0, 1].set_title('Boxplot of Normally Distributed Data')
axs[0, 1].set_xlabel('Value')
axs[0, 1].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Third subplot: Q-Q plot
sample_size = 1000  # number of samples
data = np.random.normal(mu, sigma, sample_size)
stats.probplot(data, dist="norm", plot=axs[1, 0])
axs[1, 0].get_lines()[0].set_color('blue')
axs[1, 0].set_title('Normal Probability Plot')
axs[1, 0].set_xlabel('Theoretical Quantiles')
axs[1, 0].set_ylabel('Sample Quantiles')
axs[1, 0].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Fourth subplot: Empirical CDF
sample_size = 10000  # number of samples
data = np.random.normal(mu, sigma, sample_size)
sorted_data = np.sort(data)
ecdf = np.arange(1, sample_size + 1) / sample_size
axs[1, 1].step(sorted_data, ecdf, where='post', color='blue', label='Empirical CDF')
axs[1, 1].set_title('Empirical CDF of Normally Distributed Data')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('ECDF')
axs[1, 1].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)
axs[1, 1].legend()

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t, norm

# 設定不同的自由度
degrees_of_freedom = np.arange(0.1, 15, 0.5)

# 生成 x 值
x = np.linspace(-5, 5, 1000)

# 繪製不同自由度的 t 分佈線圖
plt.figure(figsize=(6, 4))
for df in degrees_of_freedom:
    y = t.pdf(x, df)
    plt.plot(x, y, alpha=0.7, color='#D7A1C5')  # 不添加標籤

# 繪製標準正態分佈 (z 分佈) 的紅線
z = norm.pdf(x)
plt.plot(x, z, label='z distribution', color='red', linewidth=2)

# 添加標題和標籤
plt.title('t-Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)
plt.legend()  # 只顯示 z 分佈的圖例

# 顯示圖形
plt.show()

# %%
#### 未完成
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# 設定自由度和樣本數
df = 2
N = 10000

# 從 t 分佈中生成 N 個樣本
samples = t.rvs(df, size=N)

# 繪製直方圖
plt.figure(figsize=(5, 3))
plt.hist(samples, bins=500, density=True, alpha=0.6, color='g', edgecolor='black')

plt.xlim([-10, 10])

# 添加標題和標籤
plt.title(f'Histogram of {N} samples from t-Distribution with df={df}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 顯示圖形
plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# 設定自由度和樣本數
df = 2
N = 1000

# 從 t 分佈中生成 N 個樣本
samples = t.rvs(df, size=N)

# 繪製箱型圖
plt.figure(figsize=(5, 3))
plt.boxplot(samples, vert=False, patch_artist=True, boxprops=dict(facecolor='g', color='black'))

# 添加標題和標籤
plt.title(f'Boxplot of {N} samples from t-Distribution with df={df}')
plt.xlabel('Value')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 顯示圖形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# 設定不同的自由度
degrees_of_freedom = np.arange(3, 30, 1)

# 生成 x 值
x = np.linspace(0, 50, 1000)

# 繪製不同自由度的卡方分佈曲線圖
plt.figure(figsize=(10, 6))
for df in degrees_of_freedom:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='blue')

# 添加標題和標籤
plt.title('Chi-Square Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)


# 顯示圖形
plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# 設定不同的自由度
degrees_of_freedom = np.arange(30, 60, 1)

# 生成 x 值
x = np.linspace(0, 100, 1000)

# 繪製不同自由度的卡方分佈曲線圖
plt.figure(figsize=(10, 6))
for df in degrees_of_freedom:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='pink')

# 添加標題和標籤
plt.title('Chi-Square Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)


# 顯示圖形
plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# 設定不同的自由度範圍
degrees_of_freedom_1 = np.arange(3, 30, 1)
degrees_of_freedom_2 = np.arange(30, 60, 1)

# 生成 x 值
x = np.linspace(0, 100, 1000)

# 繪製卡方分佈曲線圖
plt.figure(figsize=(10, 6))

# 繪製自由度範圍為 3 到 29 的藍色線
for df in degrees_of_freedom_1:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='blue')

# 繪製自由度範圍為 30 到 59 的粉色線
for df in degrees_of_freedom_2:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='pink')

# 添加標題和標籤
plt.title('Chi-Square Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 顯示圖形
plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# 設定不同的自由度範圍
degrees_of_freedom_1 = np.arange(3, 30, 1)
degrees_of_freedom_2 = np.arange(30, 60, 1)

# 生成 x 值
x = np.linspace(0, 100, 1000)

# 繪製卡方分佈曲線圖
plt.figure(figsize=(10, 6))

# 繪製自由度範圍為 3 到 29 的藍色線
for df in degrees_of_freedom_1:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='blue')

# 繪製自由度範圍為 30 到 59 的粉色線
for df in degrees_of_freedom_2:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='pink')

# 添加標題和標籤
plt.title('Chi-Square Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 顯示圖形
plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# 設定不同的自由度範圍
degrees_of_freedom_1 = np.arange(3, 30, 1)
degrees_of_freedom_2 = np.arange(30, 60, 1)

# 生成 x 值
x = np.linspace(0, 100, 1000)

# 繪製卡方分佈曲線圖
plt.figure(figsize=(10, 6))

# 繪製自由度範圍為 3 到 29 的藍色線
for df in degrees_of_freedom_1:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='blue')

# 繪製自由度範圍為 30 到 59 的粉色線
for df in degrees_of_freedom_2:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='pink')

# 添加標題和標籤
plt.title('Chi-Square Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 顯示圖形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# 設定不同的自由度範圍
degrees_of_freedom_1 = np.arange(3, 30, 1)
degrees_of_freedom_2 = np.arange(30, 60, 1)

# 生成 x 值
x = np.linspace(0, 100, 1000)

# 繪製卡方分佈曲線圖
plt.figure(figsize=(10, 6))

# 繪製自由度範圍為 3 到 29 的藍色線
for df in degrees_of_freedom_1:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='blue')

# 繪製自由度範圍為 30 到 59 的粉色線
for df in degrees_of_freedom_2:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df={df}', alpha=0.7, color='pink')

# 添加標題和標籤
plt.title('Chi-Square Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 顯示圖形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# 設定不同的自由度範圍
degrees_of_freedom_1 = np.arange(3, 30, 1)
degrees_of_freedom_2 = np.arange(30, 60, 1)

# 生成 x 值
x1 = np.linspace(0, 50, 1000)
x2 = np.linspace(0, 100, 1000)

# 創建 3x1 的子圖
fig, axs = plt.subplots(3, 1, figsize=(8, 10))

# 第一張圖: Chi-Square Distribution with Degrees of Freedom 3 to 29
for df in degrees_of_freedom_1:
    y = chi2.pdf(x1, df)
    axs[0].plot(x1, y, label=f'df={df}', alpha=0.7, color='blue')
axs[0].set_title('Chi-Square Distribution with Degrees of Freedom 3 to 29')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Probability Density Function')
axs[0].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 第二張圖: Chi-Square Distribution with Degrees of Freedom 30 to 59
for df in degrees_of_freedom_2:
    y = chi2.pdf(x2, df)
    axs[1].plot(x2, y, label=f'df={df}', alpha=0.7, color='pink')
axs[1].set_title('Chi-Square Distribution with Degrees of Freedom 30 to 59')
axs[1].set_xlabel('Value')
axs[1].set_ylabel('Probability Density Function')
axs[1].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 第三張圖: Chi-Square Distribution with Different Degrees of Freedom
for df in degrees_of_freedom_1:
    y = chi2.pdf(x2, df)
    axs[2].plot(x2, y, label=f'df={df}', alpha=0.7, color='blue')
for df in degrees_of_freedom_2:
    y = chi2.pdf(x2, df)
    axs[2].plot(x2, y, label=f'df={df}', alpha=0.7, color='pink')
axs[2].set_title('Chi-Square Distribution with Different Degrees of Freedom')
axs[2].set_xlabel('Value')
axs[2].set_ylabel('Probability Density Function')
axs[2].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 調整子圖之間的間距並顯示圖形
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# 設定不同的自由度範圍
degrees_of_freedom_1 = np.arange(3, 30, 1)
degrees_of_freedom_2 = np.arange(30, 60, 1)

# 生成 x 值
x1 = np.linspace(0, 50, 1000)
x2 = np.linspace(0, 100, 1000)

# 創建 2x1 的子圖
fig, axs = plt.subplots(2, 1, figsize=(10, 12))

# 第一張圖: Chi-Square Distribution with Different Degrees of Freedom (3 to 29)
for df in degrees_of_freedom_1:
    y = chi2.pdf(x1, df)
    axs[0].plot(x1, y, label=f'df={df}', alpha=0.7, color='blue')
axs[0].set_title('Chi-Square Distribution with Different Degrees of Freedom (3 to 29)')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Probability Density Function')
axs[0].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 第二張圖: Chi-Square Distribution with Different Degrees of Freedom (30 to 59)
for df in degrees_of_freedom_2:
    y = chi2.pdf(x2, df)
    axs[1].plot(x2, y, label=f'df={df}', alpha=0.7, color='pink')
axs[1].set_title('Chi-Square Distribution with Different Degrees of Freedom (30 to 59)')
axs[1].set_xlabel('Value')
axs[1].set_ylabel('Probability Density Function')
axs[1].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 調整子圖之間的間距並顯示圖形
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f
import itertools

# 設定不同的自由度範圍
df1_range = np.arange(3, 30, 3)
df2_range = np.arange(3, 30, 3)

# 生成所有可能的自由度組合
degrees_of_freedom = list(itertools.product(df1_range, df2_range))

# 生成 x 值
x = np.linspace(0, 5, 1000)

# 繪製不同自由度組合的 F 分佈線圖
plt.figure(figsize=(10, 6))
for df1, df2 in degrees_of_freedom:
    y = f.pdf(x, df1, df2)
    plt.plot(x, y, label=f'df1={df1}, df2={df2}', alpha=0.7, color='#549ED7', linewidth=0.8)

# 添加標題和標籤
plt.title('F-Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

plt.xlim([0, 5])
plt.ylim([0, 1.2])

# 顯示圖形
plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f
import itertools

# 設定不同的自由度範圍
df1_range = np.arange(30, 120, 5)
df2_range = np.arange(30, 120, 5)

# 生成所有可能的自由度組合
degrees_of_freedom = list(itertools.product(df1_range, df2_range))

# 生成 x 值
x = np.linspace(0, 5, 1000)


# 繪製不同自由度組合的 F 分佈線圖
plt.figure(figsize=(10, 6))
for df1, df2 in degrees_of_freedom:
    if df1 == 100 and df2 == 100:
        plt.plot(x, f.pdf(x, df1, df2), label=f'df1={df1}, df2={df2}', alpha=0.5, color='red', linewidth=5)
    else:
        plt.plot(x, f.pdf(x, df1, df2), label=f'df1={df1}, df2={df2}', alpha=0.5, color='#4CC053', linewidth=0.8)

# 添加標題和標籤
plt.title('F-Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

plt.xlim([0, 5])
plt.ylim([0, 2.5])

red_line = plt.Line2D([0], [0], color='red', linewidth=5, label='df1=100, df2=100')
plt.legend(handles=[red_line])

# 顯示圖形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f
import itertools

# 設定不同的自由度範圍
df1_range_1 = np.arange(3, 30, 3)
df2_range_1 = np.arange(3, 30, 3)
df1_range_2 = np.arange(30, 120, 5)
df2_range_2 = np.arange(30, 120, 5)

# 生成所有可能的自由度組合
degrees_of_freedom_1 = list(itertools.product(df1_range_1, df2_range_1))
degrees_of_freedom_2 = list(itertools.product(df1_range_2, df2_range_2))

# 生成 x 值
x1 = np.linspace(0, 5, 1000)
x2 = np.linspace(0, 5, 1000)

# 創建 2x1 的子圖
fig, axs = plt.subplots(2, 1, figsize=(10, 12))

# 第一張圖: F-Distribution with Different Degrees of Freedom (3 to 30)
for df1, df2 in degrees_of_freedom_1:
    y = f.pdf(x1, df1, df2)
    axs[0].plot(x1, y, label=f'df1={df1}, df2={df2}', alpha=0.7, color='#549ED7', linewidth=0.8)
axs[0].set_title('F-Distribution with Different Degrees of Freedom (3 to 30)')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Probability Density Function')
axs[0].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)
axs[0].set_xlim([0, 5])
axs[0].set_ylim([0, 1.2])

# 第二張圖: F-Distribution with Different Degrees of Freedom (30 to 120)
for df1, df2 in degrees_of_freedom_2:
    if df1 == 100 and df2 == 100:
        axs[1].plot(x2, f.pdf(x2, df1, df2), label=f'df1={df1}, df2={df2}', alpha=0.5, color='red', linewidth=5)
    else:
        axs[1].plot(x2, f.pdf(x2, df1, df2), alpha=0.5, color='#4CC053', linewidth=0.8)
axs[1].set_title('F-Distribution with Different Degrees of Freedom (30 to 120)')
axs[1].set_xlabel('Value')
axs[1].set_ylabel('Probability Density Function')
axs[1].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)
axs[1].set_xlim([0, 5])
axs[1].set_ylim([0, 2.5])

# 只顯示紅色線條的圖例
red_line = plt.Line2D([0], [0], color='red', linewidth=5, label='df1=100, df2=100')
axs[1].legend(handles=[red_line])

# 調整子圖之間的間距並顯示圖形
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f
import itertools

# 設定不同的自由度範圍
df1_range = np.arange(30, 120, 5)
df2_range = np.arange(30, 120, 5)

# 生成所有可能的自由度組合
degrees_of_freedom = list(itertools.product(df1_range, df2_range))

# 生成 x 值
x = np.linspace(0, 5, 1000)


# 繪製不同自由度組合的 F 分佈線圖
plt.figure(figsize=(10, 6))
for df1, df2 in degrees_of_freedom:
    if df1 == 100 and df2 == 100:
        plt.plot(x, f.pdf(x, df1, df2), label=f'df1={df1}, df2={df2}', alpha=0.5, color='red', linewidth=5)
    else:
        plt.plot(x, f.pdf(x, df1, df2), label=f'df1={df1}, df2={df2}', alpha=0.5, color='#4CC053', linewidth=0.8)

# 添加標題和標籤
plt.title('F-Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

plt.xlim([0, 5])
plt.ylim([0, 2.5])

red_line = plt.Line2D([0], [0], color='red', linewidth=5, label='df1=100, df2=100')
plt.legend(handles=[red_line])

# 顯示圖形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f
import itertools

# 設定不同的自由度範圍
df1_range = np.arange(90, 101, 1)
df2_range = np.arange(90, 101, 1)

# 生成所有可能的自由度組合
degrees_of_freedom = list(itertools.product(df1_range, df2_range))

# 生成 x 值
x = np.linspace(0, 5, 1000)

# 繪製不同自由度組合的 F 分佈線圖
plt.figure(figsize=(10, 6))
for df1, df2 in degrees_of_freedom:
    if df1 == 100 and df2 == 100:
        plt.plot(x, f.pdf(x, df1, df2), label=f'df1={df1}, df2={df2}', alpha=0.7, color='red', linewidth=2)
    else:
        plt.plot(x, f.pdf(x, df1, df2), label=f'df1={df1}, df2={df2}', alpha=0.7, color='#4CC053', linewidth=0.8)

# 添加標題和標籤
plt.title('F-Distribution with Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

plt.xlim([0, 5])
plt.ylim([0, 2])

# 顯示圖形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta
import itertools

# 設定 alpha 固定值和 beta 的範圍
alpha_fixed = 10
beta_range = np.arange(1, 50, 1)

# 生成所有可能的參數組合
alpha_beta_pairs = [(alpha_fixed, beta_val) for beta_val in beta_range]

# 生成 x 值
x = np.linspace(0, 1, 1000)

# 繪製不同參數組合的 Beta 分佈線圖
plt.figure(figsize=(5, 3))
for alpha, beta_val in alpha_beta_pairs:
    y = beta.pdf(x, alpha, beta_val)
    plt.plot(x, y, label=f'alpha={alpha}, beta={beta_val}', alpha=0.7, color='#C5C950')

# 添加標題和標籤
plt.title('Beta Distribution with Different Beta Parameters(Alpha = 10)')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)


# 顯示圖形
plt.show()



import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# 設定 alpha 的範圍和 beta 固定值
alpha_range = np.arange(1, 50, 1)
beta_fixed = 10

# 生成 x 值
x = np.linspace(0, 1, 1000)

# 繪製不同 alpha 值的 Beta 分佈線圖
plt.figure(figsize=(5, 3))
for alpha in alpha_range:
    y = beta.pdf(x, alpha, beta_fixed)
    plt.plot(x, y, label=f'alpha={alpha}', alpha=0.7, color='#C5C950')

# 添加標題和標籤
plt.title('Beta Distribution with Different Alpha Parameters (Beta = 10)')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)


# 顯示圖形
plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# 設定 alpha 和 beta 的範圍
alpha_beta_range = np.arange(1, 30, 2)

# 生成 x 值
x = np.linspace(0, 1, 1000)

# 繪製 alpha = beta 的 Beta 分佈線圖
plt.figure(figsize=(5, 3))
for alpha_beta in alpha_beta_range:
    y = beta.pdf(x, alpha_beta, alpha_beta)
    plt.plot(x, y, label=f'alpha=beta={alpha_beta}', alpha=0.8, linewidth=1.3, color='#C5C950')

# 添加標題和標籤
plt.title('Beta Distribution with Alpha = Beta(Alpha = Beta)')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)


# 顯示圖形
plt.show()

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta
import itertools

# 設定 alpha 和 beta 的範圍
alpha_range = np.arange(1, 10, 2)
beta_range = np.arange(1, 10, 2)

# 生成所有可能的參數組合
alpha_beta_pairs = list(itertools.product(alpha_range, beta_range))

# 生成 x 值
x = np.linspace(0, 1, 1000)

# 繪製不同參數組合的 Beta 分佈線圖
plt.figure(figsize=(5, 3))
for alpha, beta_val in alpha_beta_pairs:
    y = beta.pdf(x, alpha, beta_val)
    plt.plot(x, y, alpha=0.8, color='#C5C950', linewidth=1.3)

# 添加標題和標籤
plt.title('Beta Distribution with Different Alpha and Beta Parameters')
plt.xlabel('Value')
plt.ylabel('Probability Density Function')
plt.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 顯示圖形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta
import itertools

# 設定 alpha 固定值和 beta 的範圍
alpha_fixed = 10
beta_range = np.arange(1, 50, 1)

# 生成所有可能的參數組合
alpha_beta_pairs = [(alpha_fixed, beta_val) for beta_val in beta_range]

# 生成 x 值
x = np.linspace(0, 1, 1000)

# 創建 2x2 的子圖
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# 第一張圖: Beta Distribution with Different Beta Parameters (Alpha = 10)
for alpha, beta_val in alpha_beta_pairs:
    y = beta.pdf(x, alpha, beta_val)
    axs[0, 0].plot(x, y, alpha=0.7, color='#C5C950')
axs[0, 0].set_title('Beta Distribution with Different Beta Parameters (Alpha = 10)')
axs[0, 0].set_xlabel('Value')
axs[0, 0].set_ylabel('Probability Density Function')
axs[0, 0].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 設定 alpha 的範圍和 beta 固定值
alpha_range = np.arange(1, 50, 1)
beta_fixed = 10

# 第二張圖: Beta Distribution with Different Alpha Parameters (Beta = 10)
for alpha in alpha_range:
    y = beta.pdf(x, alpha, beta_fixed)
    axs[0, 1].plot(x, y, alpha=0.7, color='#C5C950')
axs[0, 1].set_title('Beta Distribution with Different Alpha Parameters (Beta = 10)')
axs[0, 1].set_xlabel('Value')
axs[0, 1].set_ylabel('Probability Density Function')
axs[0, 1].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 設定 alpha 和 beta 的範圍
alpha_beta_range = np.arange(1, 30, 2)

# 第三張圖: Beta Distribution with Alpha = Beta
for alpha_beta in alpha_beta_range:
    y = beta.pdf(x, alpha_beta, alpha_beta)
    axs[1, 0].plot(x, y, alpha=0.8, linewidth=1.3, color='#C5C950')
axs[1, 0].set_title('Beta Distribution with Alpha = Beta')
axs[1, 0].set_xlabel('Value')
axs[1, 0].set_ylabel('Probability Density Function')
axs[1, 0].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 設定 alpha 和 beta 的範圍
alpha_range = np.arange(1, 10, 2)
beta_range = np.arange(1, 10, 2)

# 生成所有可能的參數組合
alpha_beta_pairs = list(itertools.product(alpha_range, beta_range))

# 第四張圖: Beta Distribution with Different Alpha and Beta Parameters
for alpha, beta_val in alpha_beta_pairs:
    y = beta.pdf(x, alpha, beta_val)
    axs[1, 1].plot(x, y, alpha=0.8, color='#C5C950', linewidth=1.3)
axs[1, 1].set_title('Beta Distribution with Different Alpha and Beta Parameters')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('Probability Density Function')
axs[1, 1].grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# 調整子圖之間的間距並顯示圖形
plt.tight_layout()
plt.show()
